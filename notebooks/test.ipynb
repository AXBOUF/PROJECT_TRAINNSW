# %%
print("Kernel Status")
# Out:
# Kernel Status

# %%
from pyspark.sql import SparkSession
import pandas as pd 
import numpy as np

# %%
# low_memory=False reads entire file first, then determines types
df = pd.read_csv("../gtfs_data/stop_times.txt", low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5256539 entries, 0 to 5256538
# Data columns (total 11 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   trip_id              str
#  1   arrival_time         str
#  2   departure_time       str
#  3   stop_id              str
#  4   stop_sequence        int64
#  5   stop_headsign        str
#  6   pickup_type          int64
#  7   drop_off_type        int64
#  8   shape_dist_traveled  float64
#  9   timepoint            int64
#  10  stop_note            str
# dtypes: float64(1), int64(4), str(6)
# memory usage: 441.1 MB

# %%
df.isnull().sum()
# Out:
# trip_id                      0
# arrival_time                 0
# departure_time               0
# stop_id                      0
# stop_sequence                0
# stop_headsign          5254362
# pickup_type                  0
# drop_off_type                0
# shape_dist_traveled          0
# timepoint                    0
# stop_note              5232048
# dtype: int64

# %%
df.head()
# Out:
#                     trip_id arrival_time departure_time stop_id  \
# 0  1.AA51.1-SC0-1-sj2-1.1.R     22:50:00       22:50:00  254111
# 1  1.AA51.1-SC0-1-sj2-1.1.R     23:04:00       23:04:00  253572
# 2  1.AA51.1-SC0-1-sj2-1.1.R     23:20:00       23:20:00  253476
# 3  1.AA51.1-SC0-1-sj2-1.1.R     23:30:00       23:30:00  253332
# 4  1.AA55.1-11B-M-sj2-1.2.R     21:14:00       21:14:00  279018
#
#    stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0              1           NaN            0              0
# 1              2           NaN            0              0
# 2              3           NaN            0              0
# 3              4           NaN            0              0
# 4              1           NaN            0              0
#
#    shape_dist_traveled  timepoint stop_note
# 0                 0.00          1       NaN
# 1             16209.06          1       NaN
# 2             29529.33          1       NaN
# ...

# %%
# check for null values 
# dropped colums agency_phone
print(df.isnull().sum())
# Out:
# agency_id          0
# agency_name        0
# agency_url         0
# agency_timezone    0
# agency_lang        0
# dtype: int64
